# %% [markdown]
# ## <b> Desafio Telecom X - Parte 2</b>
#
# O Desafio Telecom X parte 2 oferece uma oportunidade única para aplicar conhecimentos fundamentais de estatística, regressão linear e machine learning, além de habilidades essenciais de ciência de dados, em um cenário de negócios real.
#
# ### <b>Aplicação Prática do Conhecimento</b>
#
# Neste desafio, você colocará em prática conceitos fundamentais de estatística, essenciais para entender o comportamento dos dados e embasar decisões analíticas.
#
# Um dos principais passos será preparar e separar os dados de forma adequada para a criação de modelos preditivos, garantindo que haja equilíbrio entre os dados de treino e teste — algo indispensável para a construção de modelos confiáveis.
#
# Ao realizar a análise de correlação entre variáveis, será possível identificar quais fatores mais influenciam o cancelamento de serviços (churn). Isso permitirá aplicar regressão linear como ferramenta para modelar essas relações e entender o impacto de cada variável no comportamento dos clientes.
#
# Com isso, você irá construir uma base sólida para o desenvolvimento de modelos de machine learning voltados à previsão de churn, ajudando a empresa a antecipar o risco de perda de clientes e tomar decisões estratégicas para reduzir esse impacto.
#
# Este desafio não só contribui para o seu crescimento na área de Data Science, como também demonstra na prática como a ciência de dados pode ser usada para resolver problemas reais enfrentados por empresas no mercado.
#
# ### <b>Análise e Evasão de Clientes</b>
#
# Olá, sejam bem-vindos a mais um Desafio de Data Science. Nós somos parte do time de instrutores do Programa On-Line. Por questão de acessibilidade, vamos nos autodescrever. Somos uma pessoa negra, de cabelos curtos e cacheados, tingidos de vermelho. Utilizamos óculos de grau com armação transparente. Hoje estamos diferentes, usando brincos. Também estamos com uma blusa azul escura com a logo da L'Oréal Atain. Atrás de nós, há uma parede branca com luzes azuis e roxas.
#
# <b>Celebrando o progresso e introduzindo novos desafios</b><br>
# Se vocês chegaram até aqui, é porque concluíram com sucesso a primeira parte do Telecom X. Vocês extraíram, analisaram e geraram insights valiosos para a equipe de Data Science. Parabéns! Com tudo isso feito, temos uma excelente notícia para dar. Agora vocês não são apenas assistentes de análise de dados, mas cientistas de dados. Como cientistas de dados, o trabalho vai além das análises. Até agora, ajudaram a entender o passado e o presente, e agora vão nos ajudar a entender o futuro. Sim, agora vocês vão prever a evasão dos clientes. Com a ajuda dos modelos preditivos e das estatísticas, vocês vão ajudar a responder algumas perguntas. Por exemplo, quem são os clientes com maior risco de evasão? Quais variáveis mais influenciam esse comportamento? Que tipo de perfil a empresa precisa manter mais próximo? Com todas essas perguntas respondidas e com os modelos preditivos, o churn (evasão) de clientes vai diminuir.
#
# <b>Utilizando o Trello para organização do desafio</b><br>
# Como mencionamos anteriormente, temos um Trello que vai ajudar nessa parte final do desafio do Telecom X. Vamos dar uma passada por ele para relembrar cada etapa. Temos o material de apoio que explica o passo a passo de como utilizar o Trello. Temos a seção "Pronto para Iniciar", onde está todo o passo a passo para realizar esse desafio. Vamos ver alguns passos que estão nele?
#
# <b>Criando o repositório e preparando os dados</b><br>
# Começamos com a criação do repositório no GitHub. Atenção aqui: não será possível utilizar o mesmo repositório da primeira parte do Telecom X. É necessário criar um novo repositório para compartilhar o desafio final. Após criar o GitHub, passamos para a preparação dos dados. Na primeira parte da preparação dos dados, é preciso extrair o arquivo tratado. Ou seja, na primeira parte, foi gerado um arquivo final com todo o dataset tratado. É esse dataset que será utilizado.
#
# <b>Explorando o Trello e organizando as etapas do desafio</b><br>
# Como mencionado anteriormente, temos um Trello com o passo a passo para finalizarmos este desafio. Vamos relembrar como funciona o Trello? Começamos com o material de apoio, que contém todas as informações necessárias para utilizarmos o Trello.
#
# Em seguida, passamos para o backlog, ou "pronto para iniciar", onde estão todos os passos que devemos seguir para realizar este desafio. Vamos explorar um pouco esses cards? Iniciamos com o desafio, onde estão todas as informações sobre ele. Depois, passamos para a criação do repositório. É importante prestar atenção: não podemos utilizar o mesmo repositório da parte 1 do Telecom X. Para esta segunda parte, devemos criar um novo repositório.
#
# <b>Preparando os dados e criando modelos preditivos</b><br>
# Após isso, vamos para a preparação dos dados antes da criação do machine learning, dos modelos preditivos. Começamos com a extração dos arquivos tratados. Assim que finalizamos a primeira parte, já temos os arquivos tratados, que utilizaremos para criar os modelos preditivos. Em seguida, faremos uma correlação e seleção das variáveis que utilizaremos na modelagem preditiva. Com as variáveis escolhidas, separamos os dados, criamos os modelos, fazemos a avaliação deles e, por último, realizamos uma interpretação e conclusão de todos esses modelos para finalizar o projeto.
#
# <b>Elaborando o relatório final e considerações finais</b><br>
# Para essa conclusão, devemos elaborar um relatório detalhado, destacando os fatores que mais influenciam a evasão com base nas variáveis selecionadas e o desempenho de cada modelo preditivo. Com este desafio, colocaremos em prática tudo o que aprendemos até agora na especialização em data science. Utilizaremos Python, Pandas, Scikit-learn para criar os modelos preditivos e outras bibliotecas de visualização de dados.
#
# Antes de finalizar, vamos às considerações finais e à recapitulação do que foi dito. Lembrando que não será aceito o mesmo repositório da primeira parte do DeleconX. Devemos criar um novo repositório para esta segunda parte. É necessário ter finalizado todos os cursos da terceira formação para uma melhor compreensão e para realizar este desafio. Por fim, é preciso ter concluído a primeira parte do DeleconX para poder fazer esta segunda. Considerações finalizadas, desafio dado, mãos à obra!
